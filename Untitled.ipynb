# %%
import pandas as pd
import numpy as np
import requests
from wordcloud import WordCloud
import matplotlib as mpl
import matplotlib.pyplot as plt
import glob
import xmltodict
import pprint
import geocoder
import folium
import seaborn as sns

DD_file = 'C:\\users\\student\\mypy\\data\\DD\\2015_2020_drunk_driving.csv'
f = pd.read_csv(DD_file)
f.head()
# Out:
#    적발횟수   알콜농도                 측정일시  측정 시간 측정일시_요일
# 0     1  0.083  2015-01-01 00:00:00      0       목
# 1     1  0.155  2015-01-01 00:01:00      0       목
# 2     1  0.074  2015-01-01 00:02:00      0       목
# 3     1  0.204  2015-01-01 00:02:00      0       목
# 4     1  0.174  2015-01-01 00:05:00      0       목

# %%
url = 'https://www.python.org/static/img/python-logo.png'
res = requests.get(url)

with open('C:\\users\\student\\hi.png', 'wb') as f:
    f.write(res.content)

# %%
df = pd.DataFrame(f)

# %%
df
# Out:
#         적발횟수   알콜농도                 측정일시  측정 시간 측정일시_요일
# 0          1  0.083  2015-01-01 00:00:00      0       목
# 1          1  0.155  2015-01-01 00:01:00      0       목
# 2          1  0.074  2015-01-01 00:02:00      0       목
# 3          1  0.204  2015-01-01 00:02:00      0       목
# 4          1  0.174  2015-01-01 00:05:00      0       목
# ...      ...    ...                  ...    ...     ...
# 977963     1  0.097  2020-03-31 23:57:00     23       화
# 977964     1  0.175  2020-03-31 23:57:00     23       화
# 977965     1  0.122  2020-03-31 23:57:00     23       화
# 977966     1   측정거부  2020-03-31 23:58:00     23       화
# 977967     1  0.124  2020-03-31 23:59:00     23       화
#
# [977968 rows x 5 columns]

# %%
den_count = sum(df['알콜농도'] == '측정거부')
den_sum = len(df['알콜농도'])

print('알콜농도 측정거부 비율:', den_count/den_sum)
# Out:
# 알콜농도 측정거부 비율: 0.021193944996155293

# %%
df = df.drop(df[df['알콜농도'] == '측정거부'].index)

# %%
df
# Out:
#         적발횟수   알콜농도                측정일시  측정 시간 측정일시_요일  측정월  측정년도
# 0          1  0.083 2015-01-01 00:00:00      0       목    1  2015
# 1          1  0.155 2015-01-01 00:01:00      0       목    1  2015
# 2          1  0.074 2015-01-01 00:02:00      0       목    1  2015
# 3          1  0.204 2015-01-01 00:02:00      0       목    1  2015
# 4          1  0.174 2015-01-01 00:05:00      0       목    1  2015
# ...      ...    ...                 ...    ...     ...  ...   ...
# 977962     1  0.136 2020-03-31 23:55:00     23       화    3  2020
# 977963     1  0.097 2020-03-31 23:57:00     23       화    3  2020
# 977964     1  0.175 2020-03-31 23:57:00     23       화    3  2020
# 977965     1  0.122 2020-03-31 23:57:00     23       화    3  2020
# 977967     1  0.124 2020-03-31 23:59:00     23       화    3  2020
#
# [957241 rows x 7 columns]

# %%
df_after_law = df.drop(df[df['측정일시'] < '2016-06-25'].index)
df_before_law = df.drop(df[df['측정일시'] >= '2016-06-25'].index)

# %%
df_before_law.tail()
# Out:
#         적발횟수   알콜농도                측정일시  측정 시간 측정일시_요일  측정월  측정년도
# 357872     1  0.057 2016-06-24 23:58:00     23       금    6  2016
# 357873     1  0.068 2016-06-24 23:58:00     23       금    6  2016
# 357874     1  0.053 2016-06-24 23:58:00     23       금    6  2016
# 357875     1  0.185 2016-06-24 23:59:00     23       금    6  2016
# 357876     1  0.083 2016-06-24 23:59:00     23       금    6  2016

# %%
df_after_law.head()
# Out:
#         적발횟수   알콜농도                측정일시  측정 시간 측정일시_요일  측정월  측정년도
# 357877     1  0.098 2016-06-25 00:00:00      0       토    6  2016
# 357878     1  0.145 2016-06-25 00:01:00      0       토    6  2016
# 357879     1  0.103 2016-06-25 00:01:00      0       토    6  2016
# 357880     1  0.202 2016-06-25 00:01:00      0       토    6  2016
# 357881     1  0.057 2016-06-25 00:01:00      0       토    6  2016

# %%
sns.boxplot(data = df['알콜농도'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-3d08603009ed> in <module>
# ----> 1 sns.boxplot(x = '측정월', y = '알콜농도', data = df)
#
# ~\anaconda3\lib\site-packages\seaborn\categorical.py in boxplot(x, y, hue, data, order, hue_order, orient, color, palette, saturation, width, dodge, fliersize, linewidth, whis, ax, **kwargs)
#    2245     kwargs.update(dict(whis=whis))
#    2246
# -> 2247     plotter.plot(ax, kwargs)
#    2248     return ax
#    2249
#
# ~\anaconda3\lib\site-packages\seaborn\categorical.py in plot(self, ax, boxplot_kws)
#     544     def plot(self, ax, boxplot_kws):
#     545         """Make the plot."""
# --> 546         self.draw_boxplot(ax, boxplot_kws)
#     547         self.annotate_axes(ax)
#     548         if self.orient == "h":
#
# ~\anaconda3\lib\site-packages\seaborn\categorical.py in draw_boxplot(self, ax, kws)
# ...
